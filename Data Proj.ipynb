# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive
# Out:
# /content/drive

# %%
cd My Drive
# Out:
# /content/drive/My Drive

# %%
cd Machine\ Learning
# Out:
# /content/drive/My Drive/Machine Learning

# %%
# !python preprocess_data.py --format=npz --dur=10
# Out:
#  Will be resampling at 44100 Hz
#  Will be imposing 80-20 (Train-Test) split
#  Shuffling ordering
#  Finding max shape...
#  Padding all files with silence to fit shape:
#               Channels : 2
#               Samples  : 1398029
#
#  2 classes.  class_names =  ['Abnormal', 'Normal']
#  2 CPUs detected: Parallel execution across 2 CPUs
#
# Making directory  Preproc/Train/Abnormal
#
# Making directory  Preproc/Train/Normal

# %%
# !python train_network.py --batch_size=30 --epochs=40 --val=.25
# Out:
# ['/content/drive/My Drive/Machine Learning', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages']
# 3.6.8 (default, Jan 14 2019, 11:02:34)
# [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]]
# Using TensorFlow backend.
# class_names =  ['Abnormal', 'Normal']
#        total files =  227 , going to load total_load =  210
# total files =  227 , going to load total_load =  210
#    get_sample_dimensions: RPM_ABNORMAL_44.wav.npz: melgram.shape =  (1, 96, 2731, 2)
#  melgram dimensions:  (1, 96, 2731, 2)
#
#  Loading class 1/2: 'Abnormal', File 119/119: Preproc/Train/Abnormal/RPM_ABNORMAL_1.wav.npz
#  Loading class 2/2: 'Normal', File 1/108: Preproc/Train/Normal/normal_11.wav.npz
#  MyCNN_Keras2: X_shape =  (210, 96, 2731, 2) , channels =  2
# ...

# %%
# !rm -rf Preproc

# %%
# !python eval_network.py --batch_size=30
# Out:
# Using TensorFlow backend.
# class_names =  ['Abnormal', 'Normal']
#        total files =  57 , going to load total_load =  30
# total files =  57 , going to load total_load =  30
#    get_sample_dimensions: abnormal_32.wav.npz: melgram.shape =  (1, 96, 2731, 2)
#  melgram dimensions:  (1, 96, 2731, 2)
#
#  Loading class 1/2: 'Abnormal', File 30/30: Preproc/Test/Abnormal/RPM_ABNORMAL_56.wav.npz
# class names =  ['Abnormal', 'Normal']
#  MyCNN_Keras2: X_shape =  (30, 96, 2731, 2) , channels =  2
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...
